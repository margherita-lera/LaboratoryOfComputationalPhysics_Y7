# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
simple_data=[1,2,4,5,3,6,7.5,9]
with open("simple_data.txt", 'w') as file:
    print(simple_data,file=file)

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
mat=np.random.rand(5,5)
with open("data.txt",'w') as file2:
    print(mat,file=file2)

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import re

# %%
with open("data.txt",mode='r') as file2:
    matrice=file2.read()
print(matrice)

matrice_comma=re.sub(r'[0-9] ',',',matrice)
matrice_comma=matrice_comma.replace('[','')
matrice_comma=matrice_comma.replace(']','')
print(matrice_comma)
with open("data.csv",'w') as commas:
    print(matrice_comma,file=commas)
# Out:
# [[0.03857993 0.24282354 0.28959163 0.73429334 0.11724399]
#  [0.05561005 0.61577368 0.07116095 0.0889936  0.15625476]
#  [0.63181649 0.7216323  0.43725924 0.64607021 0.71265794]
#  [0.56387483 0.93173319 0.92640158 0.36784431 0.94603344]
#  [0.66202317 0.43586628 0.68143814 0.94715311 0.77932499]]
#
# 0.0385799,0.2428235,0.2895916,0.7342933,0.11724399
#  0.0556100,0.6157736,0.0711609,0.088993, 0.15625476
#  0.6318164,0.721632, 0.4372592,0.6460702,0.71265794
#  0.5638748,0.9317331,0.9264015,0.3678443,0.94603344
#  0.6620231,0.4358662,0.6814381,0.9471531,0.77932499

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
################### DA CONFRONTARE ##################


file=open("credit_card.dat",'r')
data=file.read()
#print(data[0:123])
#19*6+4
#print(len(data))
numbers=[]
i=0
while (i<(len(data)-5)):
    number=[]
    for j in range(1,20):
        number.append(int(data[i:(i+5)],2))
        #number.append()
        i+=6 
    #print(number)
    i+=5
    #print(i)
    numbers.append(number)
print(numbers)
# Out:
# [[27, 27, 26, 28, 16, 26, 27, 27, 25, 16, 25, 27, 27, 26, 16, 25, 25, 27, 24], [25, 25, 26, 27, 16, 28, 25, 26, 27, 16, 25, 25, 26, 26, 16, 25, 25, 27, 27], [25, 27, 25, 25, 16, 24, 24, 24, 24, 16, 26, 24, 24, 24, 16, 27, 27, 26, 25], [24, 27, 27, 24, 16, 25, 24, 27, 25, 16, 25, 27, 26, 25, 16, 25, 24, 26, 24], [24, 26, 25, 25, 16, 24, 27, 24, 28, 16, 24, 26, 27, 25, 16, 26, 27, 26, 25], [26, 28, 25, 27, 16, 25, 24, 25, 27, 16, 28, 27, 28, 26, 16, 27, 25, 24, 25], [26, 27, 27, 26, 16, 28, 26, 25, 28, 16, 25, 24, 28, 27, 16, 24, 24, 24, 27], [28, 24, 26, 24, 16, 24, 25, 24, 24, 16, 27, 25, 26, 25, 16, 25, 28, 26, 26], [26, 27, 27, 26, 16, 24, 24, 25, 25, 16, 27, 25, 24, 24, 16, 27, 24, 24, 24], [27, 26, 26, 27, 16, 24, 27, 25, 27, 16, 26, 24, 25, 27, 16, 27, 27, 25, 27], [24, 25, 25, 28, 16, 28, 27, 25, 24, 16, 27, 25, 28, 25, 16, 24, 24, 24, 24], [27, 24, 26, 24, 16, 24, 24, 27, 24, 16, 26, 25, 27, 26, 16, 25, 24, 27, 27], [24, 27, 24, 28, 16, 25, 26, 28, 27, 16, 24, 27, 25, 24, 16, 
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
data = json.load(open('user_data.json'))
#print(len(data))
data_up=[]
for i in range(len(data)):
    if (data[i]['CreditCardType']=='American Express'):
        data_up.append(data[i])
with open('data.json', 'w') as file:
    json.dump(data_up, file, indent=4)

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
url= 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
import pandas as pd
data2=pd.read_csv(url)
#data.head()

data2.hist('class')
# Out:
# array([[<Axes: title={'center': 'class'}>]], dtype=object)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url0='https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1' 
data=pd.read_csv(url0)
# %matplotlib inline
data.plot.scatter("features_1","features_2",)
#data.plot.scatter("features_3","features_2",)
#data.plot.scatter("features_1","features_3",)
# Out:
# <Axes: xlabel='features_1', ylabel='features_2'>

# %% [markdown]
# 08\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
data2.to_json("mushrooms_data.json", orient="records", lines=True)
